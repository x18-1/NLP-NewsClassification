# %% [markdown]
# # BiRNN

# %% [markdown]
# 没有采用预训练模型，每个小批量进行填充

# %%
import torch
import os
import sys
import os
import sys
sys.path.append(os.path.dirname(os.path.realpath(r'D:\code\Python-Project\文本数据挖掘\WBClassify')))
from WBClassify.Utils import utils,vocab,Trie
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from collections import defaultdict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import jieba
import random

# %%
def seed_torch(seed=42):
	random.seed(seed)
	os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
	np.random.seed(seed)
	torch.manual_seed(seed)
	torch.cuda.manual_seed(seed)
	torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
	torch.backends.cudnn.benchmark = False
	torch.backends.cudnn.deterministic = True

seed_torch()

# %%
def collate_fn(data):               # 传入的数据，对数据的输出形式进行设定
    inputs = [torch.tensor(i[0]) for i in data]
    lengths = torch.tensor([len(i[0]) for i in data])
    targets = torch.tensor([i[1] for i in data], dtype=torch.long)
    # 对batch内的样本进行padding，使其具有相同长度
    inputs = pad_sequence(inputs, batch_first=True)
    return inputs, lengths, targets

train_data_loader,test_data_loader,vocab_,encoder = utils.load_data(batch_size=64,is_truncate_pad=False,collate_fn=collate_fn,
                                                                    is_dropword=True,is_gotchinese=False,method='jieba')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 0.545 seconds.
# Prefix dict has been built successfully.

# %%
for x,y,z in train_data_loader:
    print(x.shape)
    print(y)
    print(z)
    break
# Out:
# torch.Size([64, 17])
# tensor([11, 10,  9,  7, 14,  4,  9,  8, 11,  7, 13, 13, 17, 10,  6, 12, 10, 13,
#          8, 14, 10, 15,  7, 11,  9,  7,  9,  7,  9, 12, 10,  5,  9,  5,  9, 13,
#         13, 14,  6, 11,  9,  8, 13,  5, 12, 13, 12,  4,  8, 12, 10, 10, 10, 12,
#         12,  8,  8, 15,  6, 10, 11, 12,  8, 11])
# tensor([1, 3, 2, 1, 4, 0, 1, 2, 0, 1, 0, 0, 4, 1, 1, 0, 0, 4, 2, 4, 2, 4, 1, 3,
#         3, 1, 2, 1, 2, 3, 2, 1, 1, 3, 3, 3, 3, 4, 1, 3, 3, 1, 2, 2, 4, 2, 1, 2,
#         2, 1, 1, 0, 4, 2, 0, 2, 0, 4, 0, 1, 3, 3, 1, 4])

# %%
class LSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_class):
        super(LSTM, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)                   # 词向量
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=2,batch_first=True,bidirectional=True)            # LSTM
        self.output = nn.Sequential(
            nn.Linear(hidden_dim, 512),                              # 线性输出层
            nn.BatchNorm1d(512),
            nn.Linear(512,256),
            nn.Linear(256,num_class)
        )

    def forward(self, inputs, lengths):
        embeddings = self.embeddings(inputs)                                                                            # 在使用paddle_sequence的情况下不需要进行转置
        x_pack = pack_padded_sequence(embeddings, lengths.to('cpu'), batch_first=True, enforce_sorted=False)            # length要放到cpu上
        hidden, (hn, cn) = self.lstm(x_pack)
        outputs = self.output(hn[-1])
        # log_probs = F.log_softmax(outputs, dim=-1)
        return outputs
    

embedding_dim = 512
hidden_dim = 512
num_class = len(encoder.classes_)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = LSTM(len(vocab_), embedding_dim, hidden_dim, num_class)

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)
    if type(m) == nn.LSTM:
        for param in m._flat_weights_names:
            if "weight" in param:
                nn.init.xavier_uniform_(m._parameters[param])
                
model.apply(init_weights)
# Out:
# LSTM(
#   (embeddings): Embedding(15653, 512)
#   (lstm): LSTM(512, 512, num_layers=2, batch_first=True, bidirectional=True)
#   (output): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): Linear(in_features=256, out_features=5, bias=True)
#   )
# )

# %%
loss = nn.CrossEntropyLoss(reduction='none')           # 反向传播对每个分量进行求导，此处设置reduce='none'
optimizer = optim.Adam(model.parameters(), lr=0.001)    # 使用Adam优化器
num_epoch = 25
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
utils.train_with_length(model,train_data_loader,test_data_loader,loss,optimizer,num_epoch,device)
# Out:
# -----------------------------------------------------------------
# | epoch  0 | avg_loss:2.968 | train_acc:0.34 |
# | epoch  0 | avg_loss:2.452 | train_acc:0.37 |
# | epoch  0 | avg_loss:2.093 | train_acc:0.43 |
# | epoch  0 | avg_loss:1.827 | train_acc:0.47 |
# | epoch  0 | avg_loss:1.621 | train_acc:0.52 |
# | epoch  0 | avg_loss:1.585 | train_acc:0.53 |
# -----------------------------------------------------------------
# | epoch  0 | avg_loss:1.585 | train_acc:0.53 | test_acc:0.69| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  1 | avg_loss:0.325 | train_acc:0.90 |
# | epoch  1 | avg_loss:0.299 | train_acc:0.90 |
# | epoch  1 | avg_loss:0.300 | train_acc:0.90 |
# | epoch  1 | avg_loss:0.308 | train_acc:0.90 |
# | epoch  1 | avg_loss:0.318 | train_acc:0.89 |
# | epoch  1 | avg_loss:0.319 | train_acc:0.89 |
# -----------------------------------------------------------------
# | epoch  1 | avg_loss:0.319 | train_acc:0.89 | test_acc:0.72| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  2 | avg_loss:0.126 | train_acc:0.96 |
# | epoch  2 | avg_loss:0.114 | train_acc:0.96 |
# | epoch  2 | avg_loss:0.114 | train_acc:0.96 |
# | epoch  2 | avg_loss:0.113 | train_acc:0.96 |
# | epoch  2 | avg_loss:0.118 | train_acc:0.96 |
# | epoch  2 | avg_loss:0.119 | train_acc:0.96 |
# -----------------------------------------------------------------
# | epoch  2 | avg_loss:0.119 | train_acc:0.96 | test_acc:0.75| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  3 | avg_loss:0.094 | train_acc:0.96 |
# | epoch  3 | avg_loss:0.094 | train_acc:0.97 |
# | epoch  3 | avg_loss:0.090 | train_acc:0.97 |
# | epoch  3 | avg_loss:0.094 | train_acc:0.97 |
# | epoch  3 | avg_loss:0.095 | train_acc:0.97 |
# | epoch  3 | avg_loss:0.094 | train_acc:0.97 |
# -----------------------------------------------------------------
# | epoch  3 | avg_loss:0.094 | train_acc:0.97 | test_acc:0.77| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  4 | avg_loss:0.068 | train_acc:0.98 |
# | epoch  4 | avg_loss:0.079 | train_acc:0.98 |
# | epoch  4 | avg_loss:0.101 | train_acc:0.97 |
# | epoch  4 | avg_loss:0.105 | train_acc:0.97 |
# | epoch  4 | avg_loss:0.098 | train_acc:0.97 |
# | epoch  4 | avg_loss:0.096 | train_acc:0.97 |
# -----------------------------------------------------------------
# | epoch  4 | avg_loss:0.096 | train_acc:0.97 | test_acc:0.78| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  5 | avg_loss:0.035 | train_acc:0.99 |
# | epoch  5 | avg_loss:0.041 | train_acc:0.99 |
# | epoch  5 | avg_loss:0.039 | train_acc:0.99 |
# | epoch  5 | avg_loss:0.043 | train_acc:0.99 |
# | epoch  5 | avg_loss:0.047 | train_acc:0.99 |
# | epoch  5 | avg_loss:0.047 | train_acc:0.99 |
# -----------------------------------------------------------------
# | epoch  5 | avg_loss:0.047 | train_acc:0.99 | test_acc:0.78| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  6 | avg_loss:0.019 | train_acc:0.99 |
# | epoch  6 | avg_loss:0.032 | train_acc:0.99 |
# | epoch  6 | avg_loss:0.031 | train_acc:0.99 |
# | epoch  6 | avg_loss:0.037 | train_acc:0.99 |
# | epoch  6 | avg_loss:0.037 | train_acc:0.98 |
# | epoch  6 | avg_loss:0.039 | train_acc:0.98 |
# -----------------------------------------------------------------
# | epoch  6 | avg_loss:0.039 | train_acc:0.98 | test_acc:0.78| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  7 | avg_loss:0.035 | train_acc:0.99 |
# | epoch  7 | avg_loss:0.040 | train_acc:0.99 |
# | epoch  7 | avg_loss:0.048 | train_acc:0.99 |
# | epoch  7 | avg_loss:0.042 | train_acc:0.99 |
# | epoch  7 | avg_loss:0.047 | train_acc:0.99 |
# | epoch  7 | avg_loss:0.046 | train_acc:0.99 |
# -----------------------------------------------------------------
# | epoch  7 | avg_loss:0.046 | train_acc:0.99 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  8 | avg_loss:0.016 | train_acc:1.00 |
# | epoch  8 | avg_loss:0.017 | train_acc:0.99 |
# | epoch  8 | avg_loss:0.022 | train_acc:0.99 |
# | epoch  8 | avg_loss:0.029 | train_acc:0.99 |
# | epoch  8 | avg_loss:0.031 | train_acc:0.99 |
# | epoch  8 | avg_loss:0.030 | train_acc:0.99 |
# -----------------------------------------------------------------
# | epoch  8 | avg_loss:0.030 | train_acc:0.99 | test_acc:0.79| lr:0.001 |
# -----------------------------------------------------------------
# | epoch  9 | avg_loss:0.008 | train_acc:1.00 |
# | epoch  9 | avg_loss:0.011 | train_acc:1.00 |
# | epoch  9 | avg_loss:0.038 | train_acc:0.99 |
# | epoch  9 | avg_loss:0.051 | train_acc:0.99 |
# | epoch  9 | avg_loss:0.049 | train_acc:0.99 |
# | epoch  9 | avg_loss:0.048 | train_acc:0.99 |
# -----------------------------------------------------------------
# | epoch  9 | avg_loss:0.048 | train_acc:0.99 | test_acc:0.77| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 10 | avg_loss:0.169 | train_acc:0.97 |
# | epoch 10 | avg_loss:0.165 | train_acc:0.97 |
# | epoch 10 | avg_loss:0.144 | train_acc:0.97 |
# | epoch 10 | avg_loss:0.129 | train_acc:0.97 |
# | epoch 10 | avg_loss:0.117 | train_acc:0.97 |
# | epoch 10 | avg_loss:0.113 | train_acc:0.97 |
# -----------------------------------------------------------------
# | epoch 10 | avg_loss:0.113 | train_acc:0.97 | test_acc:0.77| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 11 | avg_loss:0.047 | train_acc:0.98 |
# | epoch 11 | avg_loss:0.043 | train_acc:0.98 |
# | epoch 11 | avg_loss:0.046 | train_acc:0.98 |
# | epoch 11 | avg_loss:0.050 | train_acc:0.98 |
# | epoch 11 | avg_loss:0.055 | train_acc:0.98 |
# | epoch 11 | avg_loss:0.057 | train_acc:0.98 |
# -----------------------------------------------------------------
# | epoch 11 | avg_loss:0.057 | train_acc:0.98 | test_acc:0.79| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 12 | avg_loss:0.032 | train_acc:0.99 |
# | epoch 12 | avg_loss:0.049 | train_acc:0.99 |
# | epoch 12 | avg_loss:0.042 | train_acc:0.99 |
# | epoch 12 | avg_loss:0.038 | train_acc:0.99 |
# | epoch 12 | avg_loss:0.041 | train_acc:0.99 |
# | epoch 12 | avg_loss:0.041 | train_acc:0.99 |
# -----------------------------------------------------------------
# | epoch 12 | avg_loss:0.041 | train_acc:0.99 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 13 | avg_loss:0.019 | train_acc:0.99 |
# | epoch 13 | avg_loss:0.013 | train_acc:1.00 |
# | epoch 13 | avg_loss:0.012 | train_acc:1.00 |
# | epoch 13 | avg_loss:0.011 | train_acc:1.00 |
# | epoch 13 | avg_loss:0.011 | train_acc:1.00 |
# | epoch 13 | avg_loss:0.010 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 13 | avg_loss:0.010 | train_acc:1.00 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 14 | avg_loss:0.013 | train_acc:0.99 |
# | epoch 14 | avg_loss:0.007 | train_acc:1.00 |
# | epoch 14 | avg_loss:0.013 | train_acc:1.00 |
# | epoch 14 | avg_loss:0.014 | train_acc:1.00 |
# | epoch 14 | avg_loss:0.012 | train_acc:1.00 |
# | epoch 14 | avg_loss:0.011 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 14 | avg_loss:0.011 | train_acc:1.00 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 15 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 15 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 15 | avg_loss:0.002 | train_acc:1.00 |
# | epoch 15 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 15 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 15 | avg_loss:0.001 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 15 | avg_loss:0.001 | train_acc:1.00 | test_acc:0.81| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 16 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 16 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 16 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 16 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 16 | avg_loss:0.002 | train_acc:1.00 |
# | epoch 16 | avg_loss:0.002 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 16 | avg_loss:0.002 | train_acc:1.00 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 17 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 17 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 17 | avg_loss:0.003 | train_acc:1.00 |
# | epoch 17 | avg_loss:0.002 | train_acc:1.00 |
# | epoch 17 | avg_loss:0.002 | train_acc:1.00 |
# | epoch 17 | avg_loss:0.002 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 17 | avg_loss:0.002 | train_acc:1.00 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 18 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 18 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 18 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 18 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 18 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 18 | avg_loss:0.001 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 18 | avg_loss:0.001 | train_acc:1.00 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 19 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 19 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 19 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 19 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 19 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 19 | avg_loss:0.001 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 19 | avg_loss:0.001 | train_acc:1.00 | test_acc:0.80| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 20 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 20 | avg_loss:0.002 | train_acc:1.00 |
# | epoch 20 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 20 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 20 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 20 | avg_loss:0.001 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 20 | avg_loss:0.001 | train_acc:1.00 | test_acc:0.81| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 21 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 21 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 21 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 21 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 21 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 21 | avg_loss:0.000 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 21 | avg_loss:0.000 | train_acc:1.00 | test_acc:0.81| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 22 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 22 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 22 | avg_loss:0.002 | train_acc:1.00 |
# | epoch 22 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 22 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 22 | avg_loss:0.001 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 22 | avg_loss:0.001 | train_acc:1.00 | test_acc:0.81| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 23 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 23 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 23 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 23 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 23 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 23 | avg_loss:0.001 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 23 | avg_loss:0.001 | train_acc:1.00 | test_acc:0.81| lr:0.001 |
# -----------------------------------------------------------------
# | epoch 24 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 24 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 24 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 24 | avg_loss:0.000 | train_acc:1.00 |
# | epoch 24 | avg_loss:0.001 | train_acc:1.00 |
# | epoch 24 | avg_loss:0.001 | train_acc:1.00 |
# -----------------------------------------------------------------
# | epoch 24 | avg_loss:0.001 | train_acc:1.00 | test_acc:0.81| lr:0.001 |
# -----------------------------------------------------------------------------------------
# final metris:
# | avg_loss 0.001 | train acc 1.000 | test acc 0.806 |
